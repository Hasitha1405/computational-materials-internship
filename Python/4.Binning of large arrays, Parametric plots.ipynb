# %%
import numpy as np

d1=np.arange(2000000)
d2=d1**2
d=np.vstack((d1,d2)).transpose()
d.shape
# Out:
# (2000000, 2)

# %%
import matplotlib.pyplot as plt
plt.plot(d[:,0], d[:,1], 'bo')

# %%
dbin = d[::50000]
dbin.shape
# Out:
# (40, 2)

# %%
a=7plt.plot(dbin[:,0], dbin[:,1], 'ro')

# %%
a=7
b=2

t=np.linspace(-np.pi, np.pi, 400)
x=np.sin(a*t)+ np.pi/2
y=np.sin(b*t)

plt.plot(x,y)
